# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

import matplotlib.pyplot as plt

# %%
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook"

# %% [markdown]
# # Matplotlib

# %% [markdown]
# For this excercise, we have written the following code to load the stock dataset built into plotly express.

# %%
stocks = px.data.stocks()
stocks.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %% [markdown]
# ## Question 1:
#
# Select a stock and create a suitable plot for it. Make sure the plot is readable with relevant information, such as date, values.

# %%
# YOUR CODE HERE
fig, ax = plt.subplots()
x = pd.to_datetime(stocks.date)
y = stocks.GOOG
ax.plot(x,y)
ax.set_xlabel('date', fontsize=7)
ax.set_ylabel('stock value', fontsize=7)
ax.set_title('Google Stock')
ax.tick_params(axis='x', labelsize=7)
ax.tick_params(axis='y', labelsize=7)
plt.show()

# %% [markdown]
# ## Question 2:
#
# You've already plot data from one stock. It is possible to plot multiples of them to support comparison.
# To highlight different lines, customise line styles, markers, colors and include a legend to the plot.

# %%
# YOUR CODE HERE
fig, ax = plt.subplots()
x = pd.to_datetime(stocks.date)
 
ax.plot(x,y)
ax.xaxis.set_minor_locator(plt.MaxNLocator(2))
ax.set_xlabel('date', fontsize=7)
ax.set_ylabel('stock value', fontsize=7)
ax.set_title('Google Stock')
ax.tick_params(axis='x', labelsize=7)
ax.tick_params(axis='y', labelsize=7)
plt.legend(stocks.columns, loc='center', prop={'size': 6})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/til6022/lib/python3.9/site-packages/matplotlib/axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File ~/opt/anaconda3/envs/til6022/lib/python3.9/site-packages/matplotlib/category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...

# %% [markdown]
# # Seaborn

# %% [markdown]
# First, load the [tips](https://github.com/mwaskom/seaborn-data/blob/master/tips.csv) dataset

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Question 3:
#
# Let's explore this dataset. Pose a question and create a plot that support drawing answers for your question.
#
# Some possible questions:
# - Are there differences between male and female when it comes to giving tips?
# - What attribute correlate the most with tip?

# %%
grid = sns.FacetGrid(tips, row="smoker", col="time", hue="sex", margin_titles=True)
grid.map(sns.regplot, "total_bill", "tip", x_jitter=.9)
grid.add_legend()

# %% [markdown]
# QUESTION: What attribute correlate the most with tip?
#
#
# ANSWER: According to the plots, there is barely no difference between male and female when it comes to giving tips. But there is a strong positive correlation between the total bills and tips, namely the more the total bill is, the more tip is given.

# %% [markdown]
# # Plotly Express

# %% [markdown]
# ## Question 4:
#
# Redo the above exercises (challenges 2 & 3) with plotly express. Create diagrams which you can interact with.

# %% [markdown]
# ### The stocks dataset
#
# *Hints*:
# - Turn stocks dataframe into a structure that can be picked up easily with plotly express

# %%
stocks = px.data.stocks()
stocks.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
# YOUR CODE HERE
x = pd.to_datetime(stocks['date'])
y = stocks.columns[1:-1]
fig = px.line(stocks, x, y, title='Stocks', markers=True)
fig.update_layout(xaxis_title='date', yaxis_title='stock value', title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="020cd6ce-3c0d-4878-9791-1d5b0c179985" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("020cd6ce-3c0d-4878-9791-1d5b0c179985")) {                    Plotly.newPlot(                        "020cd6ce-3c0d-4878-9791-1d5b0c179985",                        [{"hovertemplate":"variable=GOOG<br>x=%{x}<br>value=%{y}<extra></extra>","legendgroup":"GOOG","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"GOOG","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2018-01-08T00:00:00","2018-01-15T00:00:00","2018-01-22T00:00:00","2018-01-29T00:00:00","2018-02-05T00:00:00","2018-02-12T00:00:00","2018-02-19T00:00:00","2018-02-26T00:00:00","2018-03-05T00:00:00","2018
# ...

# %% [markdown]
# ### The tips dataset

# %%
# YOUR CODE HERE
df = px.data.tips()
fig = px.scatter(df, x="total_bill", y="tip", color="sex", facet_col="smoker", facet_row='time')
fig.show()
# Out:
# <div>                            <div id="497a19eb-cd4d-456d-9628-d7419f8a9f97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("497a19eb-cd4d-456d-9628-d7419f8a9f97")) {                    Plotly.newPlot(                        "497a19eb-cd4d-456d-9628-d7419f8a9f97",                        [{"hovertemplate":"sex=Female<br>time=Dinner<br>smoker=No<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Female","orientation":"v","showlegend":true,"x":[16.99,24.59,35.26,14.83,10.33,16.97,20.29,15.77,19.65,15.06,20.69,16.93,10.29,34.81,26.41,16.45,17.07,14.73,22.75,20.92,7.25,25.71,17.31,29.85,25.0,13.39,16.21,35.83,18.78],"xaxis":"x3","y":[1.01,3.61,5.0,3.02,1.67,3.5,
# ...

# %% [markdown]
# ## Question 5:
#
# Recreate the barplot below that shows the population of different continents for the year 2007.
#
# *Hints:*
#
# - Extract the 2007 year data from the dataframe. You have to process the data accordingly
# - use [plotly bar](https://plotly.com/python-api-reference/generated/plotly.express.bar)
# - Add different colors for different continents
# - Sort the order of the continent for the visualisation. Use [axis layout setting](https://plotly.com/python/reference/layout/xaxis/)
# - Add text to each bar that represents the population

# %%
#load data
df = px.data.gapminder()
df_2007 = df.query('year==2007')
df_2007
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
# YOUR CODE HERE
df_2007_new = df_2007.groupby('continent').sum().round(-6)
fig = px.bar(df_2007_new, x="pop", y=df_2007_new.index, color=df_2007_new.index, text_auto=True,
            color_discrete_sequence=["red", "green", "blue", "goldenrod", "magenta"],
            orientation='h', title='Population of Each Continents in 2007')
fig.update_layout(title_x=0.5)
fig.update_yaxes(categoryorder='total ascending')
#fig.update_layout(yaxis={'categoryorder':'total ascending'}) also works
fig.show()
# Out:
# <div>                            <div id="4731ae91-c762-4ee9-8612-5ccafbd66cb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4731ae91-c762-4ee9-8612-5ccafbd66cb4")) {                    Plotly.newPlot(                        "4731ae91-c762-4ee9-8612-5ccafbd66cb4",                        [{"alignmentgroup":"True","hovertemplate":"continent=%{y}<br>pop=%{x}<extra></extra>","legendgroup":"Africa","marker":{"color":"red","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[930000000],"xaxis":"x","y":["Africa"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"continent=%{y}<br>pop=%{x}<extra></extra>","legendgroup":"Americas","marker":{"co
# ...
